# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Siddhant\Downloads\groceries.csv",header=None,sep='\n')

# %%
df = df[0].str.split(',', expand=False)
df
# Out:
# 0       [citrus fruit, semi-finished bread, margarine,...
# 1                        [tropical fruit, yogurt, coffee]
# 2                                            [whole milk]
# 3         [pip fruit, yogurt, cream cheese, meat spreads]
# 4       [other vegetables, whole milk, condensed milk,...
#                               ...
# 9830    [sausage, chicken, beef, hamburger meat, citru...
# 9831                                  [cooking chocolate]
# 9832    [chicken, citrus fruit, other vegetables, butt...
# 9833    [semi-finished bread, bottled water, soda, bot...
# 9834    [chicken, tropical fruit, other vegetables, vi...
# Name: 0, Length: 9835, dtype: object

# %%
from mlxtend.preprocessing import TransactionEncoder

# %%
te=TransactionEncoder()
te_ary=te.fit(df).transform(df)
df=pd.DataFrame(te_ary,columns=te.columns_)
df
# Out:
#       Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                     False     False             False             False
# 1                     False     False             False             False
# 2                     False     False             False             False
# 3                     False     False             False             False
# 4                     False     False             False             False
# ...                     ...       ...               ...               ...
# 9830                  False     False             False             False
# 9831                  False     False             False             False
# 9832                  False     False             False             False
# 9833                  False     False             False             False
# 9834                  False     False             False             False
#
#       baby cosmetics  baby food   bags  baking powder  bathroom cleaner  \
# ...

# %%
from mlxtend.frequent_patterns import apriori
apriori(df,min_support=0.22)
# Out:
#     support itemsets
# 0  0.255516    (166)

# %%
frequent_itemsets=apriori(df,min_support=0.02,use_colnames=True)
frequent_itemsets['length']=frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets
# Out:
#       support                                         itemsets  length
# 0    0.033452                                       (UHT-milk)       1
# 1    0.052466                                           (beef)       1
# 2    0.033249                                        (berries)       1
# 3    0.026029                                      (beverages)       1
# 4    0.080529                                   (bottled beer)       1
# ..        ...                                              ...     ...
# 117  0.032232                 (whole milk, whipped/sour cream)       2
# 118  0.020742                     (yogurt, whipped/sour cream)       2
# 119  0.056024                             (whole milk, yogurt)       2
# 120  0.023183  (whole milk, root vegetables, other vegetables)       3
# 121  0.022267           (whole milk, other vegetables, yogurt)       3
#
# [122 rows x 3 columns]

# %%
frequent_itemsets[(frequent_itemsets['length']==2) & (frequent_itemsets['support']>=0.022)]
# Out:
#       support                                itemsets  length
# 61   0.024809       (bottled water, other vegetables)       2
# 62   0.024199             (bottled water, rolls/buns)       2
# 63   0.028978                   (bottled water, soda)       2
# 64   0.034367             (bottled water, whole milk)       2
# 65   0.022979                 (bottled water, yogurt)       2
# 66   0.025216               (whole milk, brown bread)       2
# 68   0.027555                    (whole milk, butter)       2
# 69   0.028876        (citrus fruit, other vegetables)       2
# 70   0.030503              (whole milk, citrus fruit)       2
# 72   0.026131                      (whole milk, curd)       2
# 73   0.022267       (other vegetables, domestic eggs)       2
# 74   0.029995             (whole milk, domestic eggs)       2
# 78   0.026640     (whole milk, fruit/vegetable juice)       2
# 79   0.024199                 (whole milk, margarine)       2
# ...

# %%
print(df.columns)
# Out:
# Index(['Instant food products', 'UHT-milk', 'abrasive cleaner',
#        'artif. sweetener', 'baby cosmetics', 'baby food', 'bags',
#        'baking powder', 'bathroom cleaner', 'beef',
#        ...
#        'turkey', 'vinegar', 'waffles', 'whipped/sour cream', 'whisky',
#        'white bread', 'white wine', 'whole milk', 'yogurt', 'zwieback'],
#       dtype='object', length=169)

# %% [markdown]
# # ASSOCIATION RULE MINING

# %%
from mlxtend.frequent_patterns import association_rules

# %%
help(association_rules)
# Out:
# Help on function association_rules in module mlxtend.frequent_patterns.association_rules:
#
# association_rules(df, metric='confidence', min_threshold=0.8, support_only=False)
#     Generates a DataFrame of association rules including the
#     metrics 'score', 'confidence', and 'lift'
#
#     Parameters
#     -----------
#     df : pandas DataFrame
#       pandas DataFrame of frequent itemsets
#       with columns ['support', 'itemsets']
#
#     metric : string (default: 'confidence')
#       Metric to evaluate if a rule is of interest.
#       **Automatically set to 'support' if `support_only=True`.**
#       Otherwise, supported metrics are 'support', 'confidence', 'lift',
#       'leverage', and 'conviction'
#       These metrics are computed as follows:
#
#       - support(A->C) = support(A+C) [aka 'support'], range: [0, 1]
#
#       - confidence(A->C) = support(A+C) / support(A), range: [0, 1]
#
#       - lift(A->C) = confidence(A->C) / support(C), range: [0, inf]
#
# ...

# %%
rules=association_rules(frequent_itemsets, min_threshold=0.4)
rules
# Out:
#                             antecedents         consequents  \
# 0                                (beef)        (whole milk)
# 1                              (butter)        (whole milk)
# 2                                (curd)        (whole milk)
# 3                       (domestic eggs)        (whole milk)
# 4                   (frozen vegetables)        (whole milk)
# 5                           (margarine)        (whole milk)
# 6                     (root vegetables)  (other vegetables)
# 7                  (whipped/sour cream)  (other vegetables)
# 8                     (root vegetables)        (whole milk)
# 9                      (tropical fruit)        (whole milk)
# 10                 (whipped/sour cream)        (whole milk)
# 11                             (yogurt)        (whole milk)
# 12        (whole milk, root vegetables)  (other vegetables)
# 13  (root vegetables, other vegetables)        (whole milk)
# 14           (other vegetables, yogurt)        (whole milk)
#
# ...
